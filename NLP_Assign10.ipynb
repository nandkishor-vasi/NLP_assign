# %% [markdown]
# <a href="https://colab.research.google.com/github/nandkishor-vasi/NLP_assign/blob/main/NLP_Assign10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from gensim.models import KeyedVectors
from numpy.linalg import norm
import gensim.downloader as api

model = api.load("glove-wiki-gigaword-100")
def preprocess(text):
    return text.lower().split()

def sentence_vector(words):
    vectors = []
    for word in words:
        if word in model:
            vectors.append(model[word])
    if len(vectors) == 0:
        return np.zeros(model.vector_size)
    return np.mean(vectors, axis=0)

def cosine_similarity(a, b):
    return np.dot(a, b) / (norm(a) * norm(b) + 1e-10)

D = [
    "I love machine learning",
    "Artificial intelligence is fascinating",
    "I enjoy coding in python",
    "Deep learning models are powerful",
    "Best lightweight laptops for software engineering students",
    "High performance coding laptops with long battery life",
    "Affordable ultrabooks for Python and web development",
    "Top monitors and keyboards for programming setups",
    "Beginner roadmap for machine learning projects",
    "NLP interview preparation with practical examples",
    "How to optimize laptop RAM and SSD for faster builds",
    "Budget smartphones with strong camera performance",
    "Healthy weekly meal prep ideas for students",
    "Cloud deployment guide for full stack applications"
]

# %%
Q = "best laptop for coding"

Q_clean = preprocess(Q)
Q_vec = sentence_vector(Q_clean)

results = []
for sentence in D:
    words = preprocess(sentence)
    vec = sentence_vector(words)
    sim = cosine_similarity(Q_vec, vec)
    results.append((sentence, sim))

results.sort(key=lambda x: x[1], reverse=True)

# %%
print("Most Relevant Result:", results[0][0])
print("\nTop Results:")
for res, score in results:
    print(f"{res}  --> similarity: {score:.4f}")
# Out:
# Most Relevant Result: High performance coding laptops with long battery life
#
# Top Results:
# High performance coding laptops with long battery life  --> similarity: 0.8640
# Best lightweight laptops for software engineering students  --> similarity: 0.8628
# Top monitors and keyboards for programming setups  --> similarity: 0.8328
# How to optimize laptop RAM and SSD for faster builds  --> similarity: 0.8168
# Affordable ultrabooks for Python and web development  --> similarity: 0.8056
# Budget smartphones with strong camera performance  --> similarity: 0.7977
# I enjoy coding in python  --> similarity: 0.7972
# Cloud deployment guide for full stack applications  --> similarity: 0.7822
# Beginner roadmap for machine learning projects  --> similarity: 0.7656
# NLP interview preparation with practical examples  --> similarity: 0.7278
# Deep learning models are powerful  --> similarity: 0.7228
# I love machine learning  --> similarity: 0.6987
# Artificial intelligence is fascinating  --> similarity: 0.6858
# Healthy weekly meal prep ideas for students  --> similarity: 0.6815
