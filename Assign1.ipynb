# %% [markdown]
# <a href="https://colab.research.google.com/github/nandkishor-vasi/NLP_assign/blob/main/Assign1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
corpus = """
Natural Language Processing enables computers to understand human languages.
Computers are learning and processing texts efficiently.
"""

# %%
tokens = word_tokenize(corpus)
print("Tokens:")
print(tokens)
# Out:
# Tokens:
# ['Natural', 'Language', 'Processing', 'enables', 'computers', 'to', 'understand', 'human', 'languages', '.', 'Computers', 'are', 'learning', 'and', 'processing', 'texts', 'efficiently', '.']

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in tokens]

print("Stemmed Words:")
print(stemmed_words)
# Out:
# Stemmed Words:
# ['natur', 'languag', 'process', 'enabl', 'comput', 'to', 'understand', 'human', 'languag', '.', 'comput', 'are', 'learn', 'and', 'process', 'text', 'effici', '.']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in tokens]

print("Lemmatized Words:")
print(lemmatized_words)
# Out:
# Lemmatized Words:
# ['Natural', 'Language', 'Processing', 'enables', 'computer', 'to', 'understand', 'human', 'language', '.', 'Computers', 'are', 'learning', 'and', 'processing', 'text', 'efficiently', '.']
